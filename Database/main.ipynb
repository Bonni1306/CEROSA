# %%
from ipynb.fs.full.repository import exportar_usuarios_a_csv   # type: ignore
from ipynb.fs.full.Database import get_connection    # type: ignore

# %%
def run():
    print("Obteniendo datos...")
    registros = exportar_usuarios_a_csv()
    
    for r in registros:
        print(r)

if __name__ == "__main__":
    run()
